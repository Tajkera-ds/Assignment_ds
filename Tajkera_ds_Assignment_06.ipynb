# %%
import pandas as pd
import numpy as np
import warnings as wr
wr.filterwarnings('ignore')

# %%
df= pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()
df10 = df.copy()
df11 = df.copy()
df12 = df.copy()
df13 = df.copy()

# %% [markdown]
# # Replace

# %%
df3.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df3.sex.nunique()
# Out:
# 2

# %%
df3.sex= df3.sex.replace(['female','male'],[2,1])
df3.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    2  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
df3.smoker.nunique()
# Out:
# 2

# %%
df3.smoker= df3.smoker.replace(['yes','no'],[1,0])
df3.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    2  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
df3.region.nunique()
# Out:
# 4

# %%
df3.region= df3.region.replace(['southwest','southeast','northwest'],[3,2,1])
df3.head()
# Out:
#    age  sex     bmi  children  smoker region      charges
# 0   19    2  27.900         0       1      3  16884.92400
# 1   18    1  33.770         1       0      2   1725.55230
# 2   28    1  33.000         3       0      2   4449.46200
# 3   33    1  22.705         0       0      1  21984.47061
# 4   32    1  28.880         0       0      1   3866.85520

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
df4.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df4.sex= le.fit_transform(df4.sex)
df4.smoker= le.fit_transform(df4.smoker)
df4.region= le.fit_transform(df4.region)
df4.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # Loop

# %%
df5.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df5.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
for col in df5.columns:
    if df5[col].dtype==np.number:
        continue
    else:
        df5[col]=le.fit_transform(df5[[col]])

# %%
df5.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0    1    0  27.900         0       1       3  16884.92400
# 1    0    1  33.770         1       0       2   1725.55230
# 2   10    1  33.000         3       0       2   4449.46200
# 3   15    1  22.705         0       0       1  21984.47061
# 4   14    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # One Hot

# %%
df6.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dummies = pd.get_dummies(df6['sex'])
dummies.head()
# Out:
#    female  male
# 0       1     0
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %%
df6= df6.drop('sex', axis=1)
df6.head()
# Out:
#    age     bmi  children smoker     region      charges
# 0   19  27.900         0    yes  southwest  16884.92400
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520

# %%
df6 = pd.concat([df6, dummies], axis=1)
df6.head()
# Out:
#    age     bmi  children smoker     region      charges  female  male
# 0   19  27.900         0    yes  southwest  16884.92400       1     0
# 1   18  33.770         1     no  southeast   1725.55230       0     1
# 2   28  33.000         3     no  southeast   4449.46200       0     1
# 3   33  22.705         0     no  northwest  21984.47061       0     1
# 4   32  28.880         0     no  northwest   3866.85520       0     1

# %%
dummies = pd.get_dummies(df6['smoker'], drop_first=True)
dummies.head()
# Out:
#    yes
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0

# %%
df6= df6.drop('smoker', axis=1)
df6.head()
# Out:
#    age     bmi  children     region      charges  female  male
# 0   19  27.900         0  southwest  16884.92400       1     0
# 1   18  33.770         1  southeast   1725.55230       0     1
# 2   28  33.000         3  southeast   4449.46200       0     1
# 3   33  22.705         0  northwest  21984.47061       0     1
# 4   32  28.880         0  northwest   3866.85520       0     1

# %%
df6 = pd.concat([df6, dummies], axis=1)
df6.head()
# Out:
#    age     bmi  children     region      charges  female  male  yes
# 0   19  27.900         0  southwest  16884.92400       1     0    1
# 1   18  33.770         1  southeast   1725.55230       0     1    0
# 2   28  33.000         3  southeast   4449.46200       0     1    0
# 3   33  22.705         0  northwest  21984.47061       0     1    0
# 4   32  28.880         0  northwest   3866.85520       0     1    0

# %%
dummies = pd.get_dummies(df6['region'], drop_first=True)
dummies.head()
# Out:
#    northwest  southeast  southwest
# 0          0          0          1
# 1          0          1          0
# 2          0          1          0
# 3          1          0          0
# 4          1          0          0

# %%
df6= df6.drop('region', axis=1)
df6.head()
# Out:
#    age     bmi  children      charges  female  male  yes
# 0   19  27.900         0  16884.92400       1     0    1
# 1   18  33.770         1   1725.55230       0     1    0
# 2   28  33.000         3   4449.46200       0     1    0
# 3   33  22.705         0  21984.47061       0     1    0
# 4   32  28.880         0   3866.85520       0     1    0

# %%
df6 = pd.concat([df6, dummies], axis=1)
df6.head()
# Out:
#    age     bmi  children      charges  female  male  yes  northwest  \
# 0   19  27.900         0  16884.92400       1     0    1          0
# 1   18  33.770         1   1725.55230       0     1    0          0
# 2   28  33.000         3   4449.46200       0     1    0          0
# 3   33  22.705         0  21984.47061       0     1    0          1
# 4   32  28.880         0   3866.85520       0     1    0          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
df7.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()

# %% [markdown]
# # Loop

# %%
print(df7['sex'].unique())
print(df7['smoker'].unique())
print(df7['region'].unique())
# Out:
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for col in df7.columns:
    if is_numeric_dtype(df7[col]):
        continue
    else:
        one= pd.get_dummies(df7[col], drop_first=True, columns = ['sex','smoker','region'])
        df7.drop(df7[[col]], axis=1, inplace=True)
        df7=pd.concat([df7,one],axis=1)

# %%
df7.head()
# Out:
#    age     bmi  children      charges  male  yes  northwest  southeast  \
# 0   19  27.900         0  16884.92400     0    1          0          0
# 1   18  33.770         1   1725.55230     1    0          0          1
# 2   28  33.000         3   4449.46200     1    0          0          1
# 3   33  22.705         0  21984.47061     1    0          1          0
# 4   32  28.880         0   3866.85520     1    0          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Ordinal

# %%
df8.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
Sex = df8.sex.unique()
order = OrdinalEncoder(categories=[Sex])
encoded = order.fit_transform(df8[['sex']])

# %%
df8['sex']=encoded
df8.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19  0.0  27.900         0    yes  southwest  16884.92400
# 1   18  1.0  33.770         1     no  southeast   1725.55230
# 2   28  1.0  33.000         3     no  southeast   4449.46200
# 3   33  1.0  22.705         0     no  northwest  21984.47061
# 4   32  1.0  28.880         0     no  northwest   3866.85520

# %%
Smoker = df8.smoker.unique()
order = OrdinalEncoder(categories=[Smoker])
encoded = order.fit_transform(df8[['smoker']])

# %%
df8['smoker']=encoded
df8.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19  0.0  27.900         0     0.0  southwest  16884.92400
# 1   18  1.0  33.770         1     1.0  southeast   1725.55230
# 2   28  1.0  33.000         3     1.0  southeast   4449.46200
# 3   33  1.0  22.705         0     1.0  northwest  21984.47061
# 4   32  1.0  28.880         0     1.0  northwest   3866.85520

# %%
Region = df8.region.unique()
order = OrdinalEncoder(categories=[Region])
encoded = order.fit_transform(df8[['region']])

# %%
df8['smoker']=encoded
df8.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19  0.0  27.900         0     0.0  southwest  16884.92400
# 1   18  1.0  33.770         1     1.0  southeast   1725.55230
# 2   28  1.0  33.000         3     1.0  southeast   4449.46200
# 3   33  1.0  22.705         0     2.0  northwest  21984.47061
# 4   32  1.0  28.880         0     2.0  northwest   3866.85520

# %%
df8.head
# Out:
# <bound method NDFrame.head of       age  sex     bmi  children  smoker     region      charges
# 0      19  0.0  27.900         0     0.0  southwest  16884.92400
# 1      18  1.0  33.770         1     1.0  southeast   1725.55230
# 2      28  1.0  33.000         3     1.0  southeast   4449.46200
# 3      33  1.0  22.705         0     2.0  northwest  21984.47061
# 4      32  1.0  28.880         0     2.0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50  1.0  30.970         3     2.0  northwest  10600.54830
# 1334   18  0.0  31.920         0     3.0  northeast   2205.98080
# 1335   18  0.0  36.850         0     1.0  southeast   1629.83350
# 1336   21  0.0  25.800         0     0.0  southwest   2007.94500
# 1337   61  0.0  29.070         0     2.0  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %% [markdown]
# # Loop

# %%
df9.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from numpy import asarray

# %%
enc= OrdinalEncoder()

# %%
for col in df9.columns:
    if is_numeric_dtype(df9[col]):
        continue
    else:
        df9[[col]]=enc.fit_transform(df[[col]])

# %%
df9.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19  0.0  27.900         0     1.0     3.0  16884.92400
# 1   18  1.0  33.770         1     0.0     2.0   1725.55230
# 2   28  1.0  33.000         3     0.0     2.0   4449.46200
# 3   33  1.0  22.705         0     0.0     1.0  21984.47061
# 4   32  1.0  28.880         0     0.0     1.0   3866.85520
